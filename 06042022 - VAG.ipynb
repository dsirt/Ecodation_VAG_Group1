# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib as mpl
import warnings
warnings.filterwarnings("ignore")

# %%
housing = pd.read_csv('data/Housing.csv')

# %%
#Housing Dataset Subplots

# %%
fig1, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (20,20))
sns.distplot(housing["price"], ax = axes[0,0])
sns.distplot(housing["area"], ax = axes[0,1])
sns.distplot(housing["bedrooms"], ax = axes[0,2])
sns.distplot(housing["bathrooms"], ax = axes[1,0])
sns.distplot(housing["stories"], ax = axes[1,1])
sns.distplot(housing["parking"], ax = axes[1,2])
plt.show()

# %%
#Swarm Plot
exercise = pd.read_csv('data/exercise.csv', delimiter=';')
exercise.head(10)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest
# 5           5   2  low fat     93  30 min  rest
# 6           6   3  low fat     97   1 min  rest
# 7           7   3  low fat     97  15 min  rest
# 8           8   3  low fat     94  30 min  rest
# 9           9   4  low fat     80   1 min  rest

# %%
plt.figure(figsize = (7,7))
sns.swarmplot(x = "kind", y = "pulse", data = exercise)
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
plt.figure(figsize = (7,7))
sns.swarmplot(x = "kind", y = "pulse", size = 9, data = exercise)
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
plt.figure(figsize = (7,7))
sns.swarmplot(x = "kind", y = "pulse", size = 9, linewidth = 2, edgecolor = "black", data = exercise)
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
plt.figure(figsize = (7,7))
sns.swarmplot(x = "kind", y = "pulse", hue = 'diet', size = 9, data = exercise)
# Out:
# <AxesSubplot:xlabel='kind', ylabel='pulse'>

# %%
employment = pd.read_excel("data/unemployment.xlsx")
employment.head(10)
# Out:
#         When           AgeGroup         Sex  Alberta
# 0 2005-01-01     15 to 24 years     Females      6.3
# 1 2005-01-01  15 years and over       Males      4.6
# 2 2005-01-01     15 to 24 years       Males     10.4
# 3 2005-01-01  15 years and over     Females      4.4
# 4 2005-01-01  15 years and over  Both sexes      4.5
# 5 2005-01-01     15 to 24 years  Both sexes      8.4
# 6 2005-02-01     15 to 24 years  Both sexes      8.5
# 7 2005-02-01  15 years and over  Both sexes      4.1
# 8 2005-02-01  15 years and over     Females      4.0
# 9 2005-02-01     15 to 24 years       Males     10.5

# %%
plt.figure(figsize = (11, 8))
sns.swarmplot(x = employment.Alberta, palette = 'Set1', y = employment.Sex)
plt.show()

# %%
#Strip Plot

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline
sns.set_style("white")

# %%
plt.figure(figsize = (11, 8))
sns.stripplot(x = employment.Alberta)
plt.show()

# %%
plt.figure(figsize = (16, 8))
sns.stripplot(x = employment.Alberta, palette = 'Set1', y = employment.Sex)
plt.show()

# %%
plt.figure(figsize = (16, 5))
sns.stripplot(x = employment.Alberta, palette = 'Set1', y = employment.Sex, jitter=.3)
plt.show()

# %%
plt.figure(figsize = (16, 5))
sns.stripplot(x = employment.Alberta, palette = 'Set1', y = employment.AgeGroup, jitter=True)
plt.show()

# %%
#Box Plot

# %%
insurance = pd.read_csv('data/insurance.csv')
insurance.head(10)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59
# 7   37  female  27.7         3     no  northwest   7281.51
# 8   37    male  29.8         2     no  northeast   6406.41
# 9   60  female  25.8         0     no  northwest  28923.14

# %%
plt.figure(figsize = (8,6))
sns.boxplot(insurance.bmi)
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
sns.set_style("darkgrid")
plt.figure(figsize = (8, 6))
sns.boxplot(x = insurance.smoker, y = insurance.expenses)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='expenses'>

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x = insurance.smoker, y = insurance.expenses, order = ['no', 'yes']) #explicit ordering
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='expenses'>

# %%
fish = pd.read_csv("data/Fish.csv")
fish.head(10)
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 5   Bream   450.0     26.8     29.7     34.7  13.6024  4.9274
# 6   Bream   500.0     26.8     29.7     34.5  14.1795  5.2785
# 7   Bream   390.0     27.6     30.0     35.0  12.6700  4.6900
# 8   Bream   450.0     27.6     30.0     35.1  14.0049  4.8438
# 9   Bream   500.0     28.5     30.7     36.2  14.2266  4.9594

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x = fish.Species, y = fish.Weight)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Weight'>

# %%
stdperf = pd.read_csv("data/StudentsPerformance.csv")
stdperf.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
plt.subplots(figsize = (14,24))

plt.subplot(3,1,1)
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .3)

plt.subplot(3,1,2)
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['reading score'], width = .3)

plt.subplot(3,1,3)
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['writing score'], width = .3)

plt.show()

# %%
plt.figure(figsize = (14,8))
plt.text(1.5, 105, "Box Plot", fontsize = 50, color = 'Black')
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'])
plt.show()

# %%
sns.set_style("white")

# %%
plt.figure(figsize = (14,8))
plt.text(1.5, 105, "Box Plot", fontsize = 50, color = 'Black')
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = 'rainbow')
plt.show()

# %%
plt.figure(figsize = (14,8))
plt.text(1.5, 105, "Box Plot", fontsize = 50, color = 'Black')
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = {"none":'#FFB74D', "completed":'#9CCC65'})
plt.show()

# %%
plt.figure(figsize = (14,8))
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = {"none":'#FFB74D', "completed":'#9CCC65'})
sns.despine() 
plt.show()

# %%
plt.figure(figsize = (14,8))
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = {"none":'#FFB74D', "completed":'#9CCC65'})
sns.despine(left = True) 
plt.show()

# %%
plt.figure(figsize = (14,8))
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = {"none":'#FFB74D', "completed":'#9CCC65'}, linewidth = 3)
sns.despine() 
plt.show()

# %%
plt.figure(figsize = (14,8))
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = {"none":'#FFB74D', "completed":'#9CCC65'}, linewidth = 2)
sns.despine() 
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (14,8))
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = {"none":'#FFB74D', "completed":'#9CCC65'}, linewidth = 2,
           notch = True)
sns.despine() 
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (14,8))
sns.boxplot(x = stdperf['parental level of education'], y = stdperf['math score'], width = .7, 
           hue = stdperf['test preparation course'], palette = {"none":'#FFB74D', "completed":'#9CCC65'}, linewidth = 2,
           notch = True, fliersize = 10)
sns.despine() 
plt.xticks(rotation = 45)
plt.show()

# %%
#Boxen Plot

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline
sns.set_style("darkgrid")

# %%
sns.set_style("darkgrid")

# %%
plt.figure(figsize = (5,7))
sns.boxenplot(y = insurance.expenses)
plt.show()

# %%
plt.figure(figsize = (7,9))
sns.boxenplot(y = insurance.expenses, x = insurance.smoker, palette = 'Set1')
plt.show()

# %%
plt.figure(figsize = (7,9))
sns.boxenplot(y = insurance.expenses, x = insurance.children, palette = 'Set1')
plt.show()

# %%
plt.figure(figsize = (7,9))
sns.boxenplot(y = insurance.expenses, x = insurance.children, palette = "spring")
plt.show()

# %%
sns.set(rc = {"axes.facecolor" : "#616161", "axes.grid" : False})
plt.figure(figsize = (7,9))
sns.boxenplot(y = insurance.expenses, x = insurance.children, palette = 'Set1')
plt.show()

# %%
sns.set(rc = {"axes.facecolor" : "#A1C45A", "axes.grid" : False})
plt.figure(figsize = (11,9))
plt.gcf().text(.51, .84, "Box Plot", fontsize = 40, color = 'Black', ha = 'center', va = 'center')
sns.boxenplot(y = insurance.expenses, x = insurance.children, palette = 'Set1')
plt.show()

# %%
sns.set(rc = {"axes.facecolor" : "#A1C45A", "axes.grid" : False})
plt.figure(figsize = (11,9))
#plt.gcf().text(.51, .84, "Box Plot", fontsize = 40, color = 'Black', ha = 'center', va = 'center')
sns.boxenplot(x = insurance.expenses, y = insurance.region, palette = 'Set1')
plt.show()

# %%
#PAIR PLOT

# %%
fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fish1 = fish[fish['Species'].isin(['Bream', 'Perch', 'Pike'])]
fish1.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
plt.figure(figsize = (11,9))
sns.pairplot(fish1, hue = 'Species')
plt.show()

# %%
plt.figure(figsize = (11,9))
sns.pairplot(fish1, hue = 'Species', palette = "husl", size = 2)
plt.show()

# %%
sns.pairplot(fish1, hue = 'Species', vars = ["Length1", "Weight", "Height", "Width"])
plt.show()

# %%
sns.pairplot(fish1, hue = 'Species', vars = ["Length1", "Weight", "Height", "Width"],
            markers = ['o', 'D', '<'], height = 3, aspect = 1)
plt.show()

# %%
sns.pairplot(fish1, hue = 'Species', vars = ["Weight", "Height", "Width"], kind = "reg", height = 5, aspect = 1)
plt.show()

# %%
sns.pairplot(fish1, hue = 'Species', vars = ["Weight", "Height", "Width"], plot_kws = dict(s = 140), height = 5, aspect = 1)
plt.show()

# %%
sns.pairplot(fish1, hue = 'Species', vars = ["Weight", "Height", "Width"], plot_kws = dict(s = 140, linewidth = 1, alpha = .6),
             height = 5, aspect = 1)
plt.show()

# %%
#Regression Plot

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline

# %%
fish1.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
plt.figure(figsize = (7,7))
sns.regplot(x = fish1.Weight, y = fish1.Height)
plt.show()

# %%
plt.figure(figsize = (7,7))
sns.regplot(x = fish1.Weight, y = fish1.Height, color = '#FF6600')
plt.show()

# %%
plt.figure(figsize = (7,7))
sns.regplot(x = fish1.Weight, y = fish1.Height, color = '#FF6600', marker = '>')
plt.show()

# %%
plt.figure(figsize = (7,7))
sns.regplot(x = fish1.Weight, y = fish1.Height, color = '#FF6600', ci = 50, truncate = False, marker = '>')
plt.show()

# %%
plt.figure(figsize = (7,7))
sns.regplot(x = fish1.Weight, y = fish1.Height, color = '#FF6600', logx = True)
plt.show()

# %%
plt.figure(figsize = (7,7))
sns.regplot(x = fish1.Weight, y = fish1.Height, logx = True, line_kws = {"color":'#FF5722', "alpha": 0.6, "lw" : 3})
plt.show()

# %%
sns.lmplot(x = "bmi", y = "expenses", hue = "smoker", data = insurance, height = 8, aspect = 1.2)
plt.show()

# %%
sns.lmplot(x = "bmi", y = "expenses", hue = "smoker", data = insurance, height = 8, aspect = 1.2,
          scatter_kws = {'s':90, 'alpha':.4}, palette = ["#FF3333", "#00CC00"])
plt.show()

# %%
insurance.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
sns.lmplot(x = 'bmi', y = 'expenses', hue = 'smoker', col = 'sex', data = insurance, height = 6, aspect = 1.2)

# %%
sns.lmplot(x = 'bmi', y = 'expenses', hue = 'smoker', col = 'region', col_wrap = 2, data = insurance, height = 6, aspect = 1.2)

# %%
sns.lmplot(x = 'bmi', y = 'expenses', row = 'smoker', col = 'region', data = insurance, height = 6, aspect = 1.2)

# %%
#Heatmap
