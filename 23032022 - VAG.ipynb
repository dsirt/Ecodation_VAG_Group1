# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %%
plt.figure(figsize = (10,5))
x = np.array([1,2,3,4,5,6])
y1 = np.power(x, 2)
y2 = np.power(x, 3)
plt.plot(x, y1, "b-", label = '$y1 = x^2$')
plt.plot(x, y2, color = 'red', linewidth = 1.0, linestyle = '--')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(loc = 'upper center', fontsize = 'large')
plt.show()

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (16, 9))
plt.plot(x, np.sin(x), label = '$Sin(X) $ $ Dashed $', linestyle = 'dashed')
plt.plot(x+1, np.sin(x), label = '$Sin(X) $ $ Dashdot $', linestyle = 'dashdot')
plt.plot(x, np.cos(x), label = '$Cos(X) $ $ Solid $', linestyle = 'solid')
plt.plot(x+1, np.cos(x), label = '$Cos(X) $ $ Dotted $', linestyle = 'dotted')
plt.xlabel(r'$X$', fontsize = 18)
plt.ylabel(r'$Y$', fontsize = 18)
plt.title("$Sin(X) $ $ & $ $ Cos(X) $", fontsize = 14)
plt.legend(loc = 'upper right', fontsize = 14, bbox_to_anchor=(1.2, 1.0))
plt.show()

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (16, 9))
plt.plot(x, np.sin(x), label = '$Sin(X) $ $ Dashed $', linestyle = '--')
plt.plot(x+1, np.sin(x), label = '$Sin(X) $ $ Dashdot $', linestyle = '-.')
plt.plot(x, np.cos(x), label = '$Cos(X) $ $ Solid $', linestyle = '-')
plt.plot(x+1, np.cos(x), label = '$Cos(X) $ $ Dotted $', linestyle = ':')
plt.xlabel(r'$X$', fontsize = 18)
plt.ylabel(r'$Y$', fontsize = 18)
plt.title("$Sin(X) $ $ & $ $ Cos(X) $", fontsize = 14)
plt.legend(loc = 'upper right', fontsize = 14, bbox_to_anchor=(1.2, 1.0))
plt.show()

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (10, 6))
plt.plot(x, np.sin(x), label = '$Sin(X)$')
plt.plot(x, np.cos(x), label = '$Cos(X)$')
plt.fill_between(x, 0, np.sin(x))
plt.fill_between(x, 0, np.cos(x))
plt.xlabel(r'$X$', fontsize = 18)
plt.ylabel(r'$Y$', fontsize = 18)
plt.title("$Sin(X) $ $ & $ $ Cos(X) $", fontsize = 14)
plt.legend(loc = 'lower left')
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y1 = np.power(x, 2)
y2 = np.power(x, 3)
plt.plot(x, y1, "b-", label = '$y1 = x^2$')
plt.plot(x, y2, "r-", label = '$y2 = x^3$')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(loc = 'upper center', fontsize = 'large')
plt.show()

# %%
plt.figure(figsize = (10,6))
x = [1,2,3,4,5,6,7,8,9]
y = [7,8,9,10,7,11,12,13,14]
y2 = [7,7,7,7,7,7,7,7,7]
plt.plot(x, y, linewidth = 4, label = 'Line -1')
plt.plot(x, y2, linewidth = 3, label = 'Line -2')
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Line Graph')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,6))
x = [1,2,3,4,5,6,7,8,9]
y = [7,8,9,10,7,11,12,13,14]
y2 = [7,7,7,7,7,7,7,7,7]
plt.plot(x, y, linewidth = 4, label = 'Line -1')
plt.plot(x, y2, linewidth = 3, label = 'Line -2')
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Line Graph')
plt.legend()
plt.grid(b = True, linestyle = '-', which = 'major', color = 'grey')
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y1 = np.power(x, 2)
y2 = np.power(x, 3)
plt.figure(figsize = (12,5))
ax = plt.axes()
ax.set_facecolor("darkgrey")
plt.plot(x, y1, "bo-", x, y2, "ro-")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (14, 6))
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.subplot(1,2,1)
plt.plot(x, y1)
plt.subplot(1,2,2)
plt.plot(x, y2)
plt.show()

# %%
plt.figure(figsize = (12,6))
x = np.linspace(0, 10, 100)

y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x, y1, 'b-')

plt.subplot(2,1,2)
plt.plot(x, y2, 'r-')

plt.tight_layout()
plt.show()

# %%
x = np.arange(-50, 50)
y1 = np.power(x, 2)
y2 = np.power(x, 3)
y3 = np.sin(x)
y4 = np.cos(x)
y5 = np.tan(x)
y6 = np.tanh(x)
y7 = np.sinh(x)
y8 = np.cosh(x)
y9 = np.exp(x)

fig1, ax1 = plt.subplots(nrows = 3, ncols = 3, figsize = (20,20))

ax1[0,0].plot(x, y1, "tab:blue")
ax1[0,0].set_title("Square Function")
ax1[0,0].set_xlabel(r'$X$', fontsize = 18)
ax1[0,0].set_ylabel(r'$Y$', fontsize = 18)

ax1[0,1].plot(x, y2, "tab:orange")
ax1[0,1].set_title("Cubic Function")
ax1[0,1].set_xlabel(r'$X$', fontsize = 18)
ax1[0,1].set_ylabel(r'$Y$', fontsize = 18)

ax1[0,2].plot(x, y3, "tab:green")
ax1[0,2].set_title("Sine Function")
ax1[0,2].set_xlabel(r'$X$', fontsize = 18)
ax1[0,2].set_ylabel(r'$Y$', fontsize = 18)

ax1[1,0].plot(x, y4, "b-")
ax1[1,0].set_title("Cosine Function")
ax1[1,0].set_xlabel(r'$X$', fontsize = 18)
ax1[1,0].set_ylabel(r'$Y$', fontsize = 18)

ax1[1,1].plot(x, y5, "r-")
ax1[1,1].set_title("Tangent Function")
ax1[1,1].set_xlabel(r'$X$', fontsize = 18)
ax1[1,1].set_ylabel(r'$Y$', fontsize = 18)

ax1[1,2].plot(x, y6, "g-")
ax1[1,2].set_title("Hiperbolic Tangent")
ax1[1,2].set_xlabel(r'$X$', fontsize = 18)
ax1[1,2].set_ylabel(r'$Y$', fontsize = 18)

ax1[2,0].plot(x, y7, "m-")
ax1[2,0].set_title("Hiperbolic Sine")
ax1[2,0].set_xlabel(r'$X$', fontsize = 18)
ax1[2,0].set_ylabel(r'$Y$', fontsize = 18)

ax1[2,1].plot(x, y8, "y-")
ax1[2,1].set_title("Hiperbolic Cosine")
ax1[2,1].set_xlabel(r'$X$', fontsize = 18)
ax1[2,1].set_ylabel(r'$Y$', fontsize = 18)

ax1[2,2].plot(x, y9, "k-")
ax1[2,2].set_title("Exponential Function")
ax1[2,2].set_xlabel(r'$X$', fontsize = 18)
ax1[2,2].set_ylabel(r'$Y$', fontsize = 18)

plt.show()

# %%
#Bar Graphs (Çubuk Grafikler)

# %%
id1 = np.arange(1,10)
score = np.arange(20, 110, 10)
plt.bar(id1, score)
plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
id1 = np.arange(1,10)
score = np.arange(20, 110, 10)
plt.figure(figsize = (8,5))
ax = plt.axes()
ax.set_facecolor("#ECF0F1")
plt.bar(id1, score, color = '#FFA726')
plt.xlabel(r'$Student $ $ ID $')
plt.ylabel(r'$Score$')
plt.show()

# %%
x1 = [1,3,5,7]
x2 = [2,4,6,8]
y1 = [7,7,7,7]
y2 = [17,18,29,40]
plt.figure(figsize = (8,6))
ax = plt.axes()
ax.set_facecolor("white")
plt.bar(x1, y1, label = "First", color = '#42B300')
plt.bar(x2, y2, label = "Second", color = '#94E413')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar $ $ Chart $')
plt.legend()
plt.show()

# %%
Age = [28,33,43,45,57]
Name = ["Dogu", "Bati", "John", "Steve", "Arnold"]
plt.barh(Name, Age, color = "yellowgreen")
plt.show()

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize = (8,4))
plt.bar(num1, num1**2, width = 0.2, color = '#FF6F00')
plt.bar(num2, num2**2, width = 0.2, color = '#FFB300')
plt.show()

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize = (10,6))
plt.bar(num1, num1**2, width = 0.2, color = '#FF6F00')
plt.bar(num2, num2**2, width = 0.2, color = '#FFB300')
for x, y in zip(num1, num1**2):
    plt.text(x, y+0.05, '%d' % y, ha = 'center', va = 'bottom')
for x, y in zip(num2, num2**2):
    plt.text(x, y+0.05, '%d' % y, ha = 'center', va = 'bottom')
plt.show()

# %%
x = np.arange(1, 21)
plt.figure(figsize = (16,8))
y1 = np.random.uniform(0.1, 0.7, 20)
y2 = np.random.uniform(0.1, 0.7, 20)

plt.bar(x, +y1, facecolor = '#C0CA33', edgecolor = 'white')
plt.bar(x, -y2, facecolor = '#FF9800', edgecolor = 'white')

for x, y in zip(x, y1):
    plt.text(x, y + 0.05, '%.2f' % y, ha = 'center', va = 'bottom', fontsize = 10)
    
plt.xlim(0,21)
plt.ylim(-1.25, +1.25)
plt.show()

# %%
#Stacked Vertical Bar (Üst üste bindirilmiş dikey çubuk grafikler)

# %%
plt.style.use('seaborn-darkgrid')
x1 = ['Dogu', 'Bati', 'John', 'David']
y1 = [17,18,29,40]
y2 = [20,21,22,23]
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Mevcut Biletler', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satılmış Biletler', width = 0.5, bottom = y1, color = '#FFB300')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar $ $ Chart $')
plt.legend()
plt.show()

# %%
plt.style.use('seaborn-darkgrid')
x1 = ['Dogu', 'Bati', 'John', 'David']
y1 = np.array([17,18,29,40])
y2 = np.array([20,21,22,23])
y3 = np.array([5,9,11,12])
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Mevcut Biletler', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satılmış Biletler', width = 0.5, bottom = y1, color = '#FFB300')
plt.bar(x1, y3, label = 'İptal Edilmiş Biletler', width = 0.5, bottom = y1+y2, color = '#F7DC6F')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar $ $ Chart $')
plt.legend()
plt.show()

# %%
#Gruplanmış Bar Çubukları

# %%
plt.figure(figsize = (7,9))

barwidth = 0.25

y1 = np.array([17,18,29,40])
y2 = np.array([20,21,22,23])
y3 = np.array([5,9,11,12])

pos1 = np.arange(len(y1))
pos2 = [x + barwidth for x in pos1]
pos3 = [x + barwidth for x in pos2]

plt.bar(pos1, y1, label = 'Mevcut Biletler', width = barwidth, color = '#FF6F00')
plt.bar(pos2, y2, label = 'Satılmış Biletler', width = barwidth, color = '#FFB300')
plt.bar(pos3, y3, label = 'İptal Edilmiş Biletler', width = barwidth, color = '#F7DC6F')

plt.legend()
plt.show()
